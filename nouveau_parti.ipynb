# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/Users/carolinlabinski/THP_data/Jour18/resultats.csv",engine ='python',sep=";")

# %%
df1.head()
# Out:
#   Code du département   Libellé du département Etat saisie  Inscrits  \
# 0                  01                      Ain     Complet    438109
# 1                  02                    Aisne     Complet    373544
# 2                  03                   Allier     Complet    249991
# 3                  04  Alpes-de-Haute-Provence     Complet    128075
# 4                  05             Hautes-Alpes     Complet    113519
#
#    Abstentions % Abs/Ins  Votants % Vot/Ins  Blancs % Blancs/Ins  ...  \
# 0        97541     22,26   340568     77,74    5641         1,29  ...
# 1       101089     27,06   272455     72,94    3767         1,01  ...
# 2        58497      23,4   191494      76,6    3749          1,5  ...
# 3        29290     22,87    98785     77,13    1478         1,15  ...
# 4        25357     22,34    88162     77,66    1395         1,23  ...
#
#   Unnamed: 79  Unnamed: 80 Unnamed: 81 Unnamed: 82  Unnamed: 83  \
# ...

# %%
#df1['Libellé du département'].value_counts().plot.pie(autopct='%1.0f%%')
#plt.show()

# %%
df1.describe()
# Out:
#            Inscrits    Abstentions       Votants        Blancs         Nuls  \
# count  1.070000e+02     107.000000  1.070000e+02    107.000000   107.000000
# mean   4.555876e+05  119852.046729  3.357356e+05   5080.457944  2309.822430
# std    3.510038e+05  117017.797771  2.583938e+05   3492.523741  1501.382871
# min    5.045000e+03    2272.000000  2.773000e+03     27.000000    17.000000
# 25%    1.980675e+05   51659.500000  1.425685e+05   2484.000000  1202.500000
# 50%    3.668590e+05   95369.000000  2.743720e+05   4001.000000  2039.000000
# 75%    5.991175e+05  158148.500000  4.443390e+05   7336.500000  3119.500000
# max    1.813906e+06  931455.000000  1.299873e+06  17416.000000  8253.000000
#
#            Exprimés         Voix   Unnamed: 26    Unnamed: 32   Unnamed: 38  \
# count  1.070000e+02   107.000000    107.000000     107.000000    107.000000
# mean   3.283453e+05  1842.000000   7499.271028   91430.448598  10293.336449
# ...
